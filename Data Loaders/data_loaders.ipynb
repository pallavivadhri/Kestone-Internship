# %%
#CSV LOADER
from langchain_community.document_loaders.csv_loader import CSVLoader
loader = CSVLoader(file_path=r'C:\Users\palla\Downloads\diabetes.csv')
data= loader.load()
print(type(data))
print(data[0])  # first row , includes content + metadata
print(data[1].metadata)  #includes only metadata
print(data[1].page_content) #includes only content
# Out:
# <class 'list'>
# page_content='Pregnancies: 6
# Glucose: 148
# BloodPressure: 72
# SkinThickness: 35
# Insulin: 0
# BMI: 33.6
# DiabetesPedigreeFunction: 0.627
# Age: 50
# Outcome: 1' metadata={'source': 'C:\\Users\\palla\\Downloads\\diabetes.csv', 'row': 0}
# {'source': 'C:\\Users\\palla\\Downloads\\diabetes.csv', 'row': 1}
# Pregnancies: 1
# Glucose: 85
# BloodPressure: 66
# SkinThickness: 29
# Insulin: 0
# BMI: 26.6
# DiabetesPedigreeFunction: 0.351
# Age: 31
# Outcome: 0

# %%
#WEBPAGE LOADER
from langchain_community.document_loaders.web_base import WebBaseLoader
loader = WebBaseLoader("https://medium.com/@raja.gupta20/generative-ai-for-beginners-part-1-introduction-to-ai-eadb5a71f07d")
data= loader.load()
print(type(data))
print(data[0])
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# <class 'list'>
# ...

# %%
#HTML LOADER
from langchain_community.document_loaders import BSHTMLLoader

loader = BSHTMLLoader(
    file_path=r"C:\Users\palla\Downloads\large sample html file download for testing.html",
)
docs = loader.load()
docs[0]
# Out:
# Document(metadata={'source': 'C:\\Users\\palla\\Downloads\\large sample html file download for testing.html', 'title': ''}, page_content='\n\n\n1st column\n2nd column\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, column 2\n\n\nRow 1, column 1\nRow 1, colu
# ...

# %%
#PDF LOADER
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader(file_path=r'C:\Users\palla\Downloads\Startup.pdf')
data= loader.load()
print(type(data))
print(data[1].page_content)
# Out:
# <class 'list'>
# Introduction
# Traditional deep convolutional neural networks (CNNs) like LeNet5 (5 layers), VGG (19 layers), and ResNets (over 100
# layers) have grown deeper over time. But as networks deepen, issues like vanishing gradients and information loss
# emerge.
# In very deep networks, information and gradients may diminish as they pass through many layers, making training
# difficult.
# Previous Solutions:
# ResNets and Highway Networks use identity connections to bypass layers and improve gradient flow.1.
# Stochastic Depth randomly skips layers during training.2.
# FractalNets use multiple parallel paths to maintain short connections.3.
# Proposed Solution – DenseNet:
#    1.Dense Connectivity: Every layer is connected to all previous layers using concatenation (not summation like in
# ResNets).
#    2. If there are L layers, there are L(L+1)/2 connections instead of just L.
# ...

# %%
#JSON 
from langchain_community.document_loaders import JSONLoader

loader = JSONLoader(
    file_path=r"C:\Users\palla\Downloads\package.json",
    jq_schema=".scripts",  #which part of json to extract
    text_content=False,    #true for strings, false for anything else
)
data= loader.load()
print(type(data))
print(data[0].page_content)
# Out:
# <class 'list'>
# {"dev": "tsx watch src/bin.ts fixtures/db.json", "build": "rm -rf lib && tsc", "test": "node --import tsx/esm --test src/*.test.ts", "lint": "eslint src", "prepare": "husky", "prepublishOnly": "npm run build"}

# %%
#MONGO DB
from langchain_community.document_loaders.mongodb import MongodbLoader
import nest_asyncio  #prevents run-time errors during nested async calls
nest_asyncio.apply()

loader = MongodbLoader(
    connection_string= "mongodb+srv://vadhri:scBf3RaqaDSsTwxi@cluster0.dotrgan.mongodb.net/",
    db_name="sample_restaurants",
    collection_name="restaurants",
    filter_criteria={"borough": "Bronx", "cuisine": "Bakery"},
    field_names=["name", "address"],
)
docs = loader.load()
print(docs[0])
len(docs)
# Out:
# page_content='Morris Park Bake Shop {'building': '1007', 'coord': [-73.856077, 40.848447], 'street': 'Morris Park Ave', 'zipcode': '10462'}' metadata={'database': 'sample_restaurants', 'collection': 'restaurants'}
# 71

# %%
#MONGO DB
from langchain_community.document_loaders.mongodb import MongodbLoader
import nest_asyncio  #prevents run-time errors during nested async calls
nest_asyncio.apply()

loader = MongodbLoader(
    connection_string= "mongodb+srv://vadhri:scBf3RaqaDSsTwxi@cluster0.dotrgan.mongodb.net/" ,
    db_name="Cooking",
    collection_name="Ingredients",
    filter_criteria={"used_in": "Pasta"},
    field_names=["ingredient", "type"],
)
docs = loader.load()
print(docs[0])
len(docs)
# Out:
# page_content='Tomato Vegetable' metadata={'database': 'Cooking', 'collection': 'Ingredients'}
# 2

# %%
#SQL DB
from langchain_community.document_loaders import SQLDatabaseLoader
from langchain_community.utilities import SQLDatabase
from sqlalchemy import create_engine

connection_string = "mysql+pymysql://root:root@localhost:3306/demo_excel"
engine = create_engine(connection_string)

db = SQLDatabase(engine)
query = "SELECT * FROM demo_excel.demo" 
#param = { "age" : "30"}

loader = SQLDatabaseLoader(
    db=db, 
    query=query,
    #parameters=param,
)
docs = loader.load()
for doc in docs:
    print(doc.page_content)
# Out:
# Name: Alice
# Age: 28
# City: New York
# Name: Bob
# Age: 34
# City: Los Angeles
# Name: Charlie
# Age: 22
# City: Chicago
# Name: Diana
# Age: 45
# City: Houston
# Name: Edward
# Age: 31
# City: Phoenix
# Name: Fiona
# Age: 27
# City: Philadelphia
# Name: George
# Age: 38
# City: San Antonio
# Name: Hannah
# Age: 30
# City: San Diego
# Name: Ian
# Age: 25
# City: Dallas
# Name: Julia
# Age: 29
# City: San Jose
